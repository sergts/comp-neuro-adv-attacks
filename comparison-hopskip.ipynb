# %%
import os
import argparse
import time
import glob
import pickle
import subprocess
import shlex
import io
import pprint
import importlib
from urllib.request import urlopen
from IPython.display import Image as dispImg
import scipy.io
import numpy as np
import pandas
import tqdm
import fire
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.utils.model_zoo
import torchvision
from art.classifiers import PyTorchClassifier
import cornet
from art.attacks import BoundaryAttack
from art.attacks import HopSkipJump
from imgaug import augmenters as iaa
import imgaug as ia
#attack = HopSkipJump(classifier=classifier, targeted=False, max_iter=0, max_eval=1000, init_eval=10)
from art.attacks import FastGradientMethod
from art.attacks import ElasticNet
from art.attacks import ProjectedGradientDescent

from PIL import Image
Image.warnings.simplefilter('ignore')

ia.seed(1)
np.random.seed(0)
torch.manual_seed(0)

mean = torch.tensor([0.44, 0.44, 0.44], dtype=torch.float32)
std = torch.tensor([0.225, 0.225, 0.225], dtype=torch.float32)
normalize = torchvision.transforms.Normalize(mean=[0.44, 0.44, 0.44],
                                             std=[0.225, 0.225, 0.225])
transform = torchvision.transforms.Compose([
                torchvision.transforms.Resize(256),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                normalize
            ])
unnormalize = torchvision.transforms.Normalize((-mean / std).tolist(), (1.0 / std).tolist())

def get_model(model_size='z', cuda=False):
    map_location = 'cpu' if not cuda else None
    #map_location = None
    model = getattr(cornet, f'cornet_{model_size.lower()}')
    if model_size.lower() == 'r':
        model = model(pretrained=True, map_location=map_location, times=5)
    else:
        model = model(pretrained=True, map_location=map_location)
    if cuda:
        model = model.cuda()
        return model
    model.cpu()
    return model.module

sharpen = iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5), deterministic=True)


                # Same as sharpen, but for an embossing effect.
emboss = iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0), deterministic=True)

# %% [markdown]
# Load data

# %%
labels = pickle.load(open("labels.pkl", "rb" ))
y_val = np.load("D:\\imagenet2012\\y_val.npy")
print(f"{y_val.shape[0]} validation labels loaded")
data_path = 'D:\\imagenet2012\\val'
fnames = sorted(glob.glob(os.path.join(data_path, '*.*')))
print(f"{len(fnames)} files found");
# Out:
# 50000 validation labels loaded
# 50000 files found

# %%
def to_grayscale(img):
    return np.dot(img[...,:3], [0.299, 0.587, 0.114])

# %%
np.argsort((y_val == 26))[-2]
# Out:
# 48045

# %%
def get_image_by_class(image_class):
    return Image.open(fnames[np.argsort((y_val == image_class))[-1]]).convert('RGB')

# %%
def plot_augmented(original_image, adv_image):
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 16))
    axes[0, 0].imshow(to_grayscale(original_image))
    axes[0, 1].imshow(to_grayscale(adv_image))
    axes[1, 0].imshow(to_grayscale(sharpen.augment_image(original_image)))
    axes[1, 1].imshow(to_grayscale(sharpen.augment_image(adv_image)))
    axes[2, 0].imshow(to_grayscale(emboss.augment_image(original_image)))
    axes[2, 1].imshow(to_grayscale(emboss.augment_image(adv_image)))
    plt.show()

# %%
def l2(orig, adv):
    return np.linalg.norm(np.reshape(adv[0] - orig[0], [-1]))

# %%
def perform_attack(im, model_size, target_class=None, targeted=False, show_info=True, params={}):
    model = get_model(model_size)
    model.eval()
    if show_info:
        print(f'using model type: {model_size}')
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


    classifier = PyTorchClassifier(model=model, loss=criterion,
                               optimizer=optimizer, nb_classes=1000, input_shape=(3,224,224), clip_values=(-1.956, 6.4))
    attack = HopSkipJump(classifier=classifier, targeted=targeted, **params)
    
    x = transform(im).unsqueeze(0).numpy()
    
    pred = classifier.predict(x)[0]
    pred = np.exp(pred)/sum(np.exp(pred))
    if show_info:
        top_5 = np.flip(np.argsort(pred)[-5:])
        print('\nOriginal image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {pred[t]}')
        print('\nGenerating adversarial example')
    
    x_adv = attack.generate(x=transform(im).unsqueeze(0).numpy(), y=np.array([target_class]) if target_class is not None else None)
    if show_info:
        print('L2: ' + str(np.linalg.norm(np.reshape(x_adv[0] - x[0], [-1]))))
    
    original_image = np.moveaxis(unnormalize(torch.from_numpy(x[0])).numpy(),  [0, 1, 2], [2, 0, 1])
    adv_image = np.moveaxis(unnormalize(torch.from_numpy(x_adv[0])).numpy(),  [0, 1, 2], [2, 0, 1])
    pert = np.abs(adv_image - original_image)[..., ::-1]
    pert_min = np.min(pert)
    pert_max = np.max(pert)
    pert_image = -((pert - pert_min) / (pert_max - pert_min))+1
    if show_info:
        fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 16))
        axes[0].imshow(original_image)
        axes[1].imshow(pert_image)
        axes[2].imshow(adv_image)
    
    adv_pred = classifier.predict(x_adv)[0]
    adv_pred = np.exp(adv_pred)/sum(np.exp(adv_pred))
    if show_info:
        top_5 = np.flip(np.argsort(adv_pred)[-5:])
        print('\nAdversarial image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {adv_pred[t]}')
    
    plt.show()
    return adv_pred

# %%
i=39218
print(labels[y_val[i]])
#target 39206
# Out:
# magpie

# %%
#im = Image.open(fnames[i]).convert('RGB')
#im = Image.open("D:\\imagenet2012\junco.jpg").convert('RGB')
im = Image.open("D:\\imagenet2012\john_cleese.png").convert('RGB')
#im = Image.open(fnames[np.argsort((y_val == 26))[-3]]).convert('RGB')
im
# Out:
# <PIL.Image.Image image mode=RGB size=605x661 at 0x1DE30C790F0>

# %%
def get_classifier(model_size='z'):
    model = get_model(model_size)
    model.eval()
    print(f'using model type: {model_size}')

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


    classifier = PyTorchClassifier(model=model, loss=criterion,
                                   optimizer=optimizer, nb_classes=1000, input_shape=(3,224,224), clip_values=(-1.956, 6.4))
    return classifier

# %%
z = get_classifier()
s = get_classifier('s')
# Out:
# using model type: z
# using model type: s

# %%
def predict(classifier, im, show_info=True):

    x = transform(im).unsqueeze(0).numpy()

    pred = classifier.predict(x)[0]
    pred = np.exp(pred)/sum(np.exp(pred))
    if show_info:
        top_5 = np.flip(np.argsort(pred)[-5:])
        print('\nOriginal image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {pred[t]}')

            plt.imshow(np.moveaxis(unnormalize(torch.from_numpy(x[0])).numpy(),  [0, 1, 2], [2, 0, 1]))
            plt.show()
    return pred

# %%
def random_exclude(high, exclude=[]):
    tries_left = 5
    while tries_left > 1:
        num = np.random.randint(high)
        tries_left -= 1
        if num not in exclude:
            return num
    raise Exception('Could not generate random number')

# %%
images_used = []
targets = []
fooled_s = []
fooled_z = [] 
confused_z = []
confused_s = []
#300 iter
while len(images_used) < 100:
    
    random_int = np.random.randint(50000)
    if random_int in images_used:
        continue
    im = Image.open(fnames[random_int]).convert('RGB')
    true_label = y_val[random_int]
    
    pred_z = predict(z, im, False)
    label_z = np.argmax(pred_z)
    if true_label != label_z or pred_z[label_z] < 0.5:
        continue
    pred_s = predict(s, im, False)
    label_s = np.argmax(pred_s)
    if true_label != label_s or pred_s[label_s] < 0.5:
        continue
    #images are correctly recognized before attacks
    images_used.append(random_int)
    
    target = random_exclude(1000, [true_label])
    targets.append(target)
    
    adv_z = perform_attack(im, 'z', target, True, show_info=True)
    adv_s = perform_attack(im, 's', target, True, show_info=False)
    
    adv_class_z = np.argmax(adv_z)
    adv_class_s = np.argmax(adv_s)
    
    fooled_z.append(target == adv_class_z and adv_z[adv_class_z] >= 0.5)
    fooled_s.append(target == adv_class_s and adv_s[adv_class_s] >= 0.5)
    confused_z.append(adv_class_z != true_label)
    confused_s.append(adv_class_s != true_label)
    
    print('Fooled z:')
    print(np.array(fooled_z).sum())
    print('Fooled s:')
    print(np.array(fooled_s).sum())
    print(f'images processed: {len(images_used)}')

print('Fooled z %:')
print(np.array(fooled_z).sum() / len(images_used) * 100)
print('Fooled s %:')
print(np.array(fooled_s).sum() / len(images_used) * 100)


print('Confused z %:')
print(np.array(confused_z).sum() / len(images_used) * 100)
print('Confused s %:')
print(np.array(confused_s).sum() / len(images_used) * 100)
# Out:
# using model type: z
#
# Original image predictions:
# cliff dwelling (500): 0.9996338486671448
# lumbermill, sawmill (634): 0.00014453682524617761
# crate (519): 3.82372090825811e-05
# bakery, bakeshop, bakehouse (415): 8.545574928575661e-06
# vault (884): 7.227216428873362e-06
#
# Generating adversarial example
# L2: 0.0
#
# Adversarial image predictions:
# cliff dwelling (500): 0.9996338486671448
# lumbermill, sawmill (634): 0.00014453682524617761
# crate (519): 3.82372090825811e-05
# bakery, bakeshop, bakehouse (415): 8.545574928575661e-06
# vault (884): 7.227216428873362e-06
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 1
# using model type: z
#
# Original image predictions:
# lionfish (396): 0.9999520778656006
# sea anemone, anemone (108): 1.5114216694200877e-05
# conch (112): 1.5103669284144416e-05
# sea slug, nudibranch (115): 1.3916036550654098e-05
# coral reef (973): 8.029836635614629e-07
#
# Generating adversarial example
# L2: 0.0
#
# Adversarial image predictions:
# lionfish (396): 0.9999520778656006
# sea anemone, anemone (108): 1.5114216694200877e-05
# conch (112): 1.5103669284144416e-05
# sea slug, nudibranch (115): 1.3916036550654098e-05
# coral reef (973): 8.029836635614629e-07
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 2
# using model type: z
#
# Original image predictions:
# fig (952): 0.7762911915779114
# pomegranate (957): 0.07933029532432556
# acorn squash (941): 0.01814514771103859
# orange (950): 0.015787452459335327
# bolete (997): 0.012720402330160141
#
# Generating adversarial example
# L2: 0.0
#
# Adversarial image predictions:
# fig (952): 0.7762911915779114
# pomegranate (957): 0.07933029532432556
# acorn squash (941): 0.01814514771103859
# orange (950): 0.015787452459335327
# bolete (997): 0.012720402330160141
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 3
# using model type: z
#
# Original image predictions:
# palace (698): 0.9756471514701843
# monastery (663): 0.008431428112089634
# castle (483): 0.006042288150638342
# dome (538): 0.0030501680448651314
# mosque (668): 0.0021528464276343584
#
# Generating adversarial example
# L2: 0.0
#
# Adversarial image predictions:
# palace (698): 0.9756471514701843
# monastery (663): 0.008431428112089634
# castle (483): 0.006042288150638342
# dome (538): 0.0030501680448651314
# mosque (668): 0.0021528464276343584
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6d80b8945487> in <module>
#      29
#      30     adv_z = perform_attack(im, 'z', target, True, show_info=True)
# ---> 31     adv_s = perform_attack(im, 's', target, True, show_info=False)
#      32
#      33     adv_class_z = np.argmax(adv_z)
#
# <ipython-input-16-52d532e38cfb> in perform_attack(im, model_size, target_class, targeted, show_info, params)
#       1 def perform_attack(im, model_size, target_class=None, targeted=False, show_info=True, params={}):
# ----> 2     model = get_model(model_size)
#       3     model.eval()
#       4     if show_info:
#       5         print(f'using model type: {model_size}')
#
# <ipython-input-1-d6f8db6551b3> in get_model(model_size, cuda)
#      58         model = model(pretrained=True, map_location=map_location, times=5)
#      59     else:
# ---> 60         model = model(pretrained=True, map_location=map_location)
#      61     if cuda:
#      62         model = model.cuda()
#
# ~\Desktop\cornet\CORnet\cornet\__init__.py in cornet_s(pretrained, map_location)
#      31
#      32 def cornet_s(pretrained=False, map_location=None):
# ---> 33     return get_model('s', pretrained=pretrained, map_location=map_location)
#
# ~\Desktop\cornet\CORnet\cornet\__init__.py in get_model(model_letter, pretrained, map_location, **kwargs)
#      13     model_letter = model_letter.upper()
#      14     model_hash = globals()[f'HASH_{model_letter}']
# ---> 15     model = globals()[f'CORnet_{model_letter}'](**kwargs)
#      16     model = torch.nn.DataParallel(model)
#      17     if pretrained:
#
# ~\Desktop\cornet\CORnet\cornet\cornet_s.py in CORnet_S()
#     106         ('V2', CORblock_S(64, 128, times=2)),
#     107         ('V4', CORblock_S(128, 256, times=4)),
# --> 108         ('IT', CORblock_S(256, 512, times=2)),
#     109         ('decoder', nn.Sequential(OrderedDict([
#     110             ('avgpool', nn.AdaptiveAvgPool2d(1)),
#
# ~\Desktop\cornet\CORnet\cornet\cornet_s.py in __init__(self, in_channels, out_channels, times)
#      46
#      47         self.conv2 = nn.Conv2d(out_channels * self.scale, out_channels * self.scale,
# ---> 48                                kernel_size=3, stride=2, padding=1, bias=False)
#      49         self.nonlin2 = nn.ReLU(inplace=True)
#      50
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode)
#     330         super(Conv2d, self).__init__(
#     331             in_channels, out_channels, kernel_size, stride, padding, dilation,
# --> 332             False, _pair(0), groups, bias, padding_mode)
#     333
#     334     def conv2d_forward(self, input, weight):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode)
#      44         else:
#      45             self.register_parameter('bias', None)
# ---> 46         self.reset_parameters()
#      47
#      48     def reset_parameters(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in reset_parameters(self)
#      47
#      48     def reset_parameters(self):
# ---> 49         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#      50         if self.bias is not None:
#      51             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# ~\Anaconda3\lib\site-packages\torch\nn\init.py in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     317     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     318     with torch.no_grad():
# --> 319         return tensor.uniform_(-bound, bound)
#     320
#     321
#
# KeyboardInterrupt:

# %%
images_used = []
targets = []
fooled_s = []
fooled_z = [] 
confused_z = []
confused_s = []
#1000 maxiter
while len(images_used) < 10:
    
    random_int = np.random.randint(50000)
    if random_int in images_used:
        continue
    im = Image.open(fnames[random_int]).convert('RGB')
    true_label = y_val[random_int]
    
    pred_z = predict(z, im, False)
    label_z = np.argmax(pred_z)
    if true_label != label_z or pred_z[label_z] < 0.5:
        continue
    pred_s = predict(s, im, False)
    label_s = np.argmax(pred_s)
    if true_label != label_s or pred_s[label_s] < 0.5:
        continue
    #images are correctly recognized before attacks
    images_used.append(random_int)
    
    target = random_exclude(1000, [true_label])
    targets.append(target)
    
    adv_z = perform_attack(im, 'z', target, True, show_info=False)
    adv_s = perform_attack(im, 's', target, True, show_info=False)
    
    adv_class_z = np.argmax(adv_z)
    adv_class_s = np.argmax(adv_s)
    
    fooled_z.append(target == adv_class_z and adv_z[adv_class_z] >= 0.5)
    fooled_s.append(target == adv_class_s and adv_s[adv_class_s] >= 0.5)
    confused_z.append(adv_class_z != true_label)
    confused_s.append(adv_class_s != true_label)
    
    print('Fooled z:')
    print(np.array(fooled_z).sum())
    print('Fooled s:')
    print(np.array(fooled_s).sum())
    print(f'images processed: {len(images_used)}')

print('Fooled z %:')
print(np.array(fooled_z).sum() / len(images_used) * 100)
print('Fooled s %:')
print(np.array(fooled_s).sum() / len(images_used) * 100)


print('Confused z %:')
print(np.array(confused_z).sum() / len(images_used) * 100)
print('Confused s %:')
print(np.array(confused_s).sum() / len(images_used) * 100)
# Out:
# Fooled z:
# 1
# Fooled s:
# 1
# images processed: 1
# Fooled z:
# 2
# Fooled s:
# 1
# images processed: 2
# Fooled z:
# 3
# Fooled s:
# 1
# images processed: 3
# Fooled z:
# 4
# Fooled s:
# 2
# images processed: 4
# Fooled z:
# 5
# Fooled s:
# 3
# images processed: 5
# Fooled z:
# 6
# Fooled s:
# 4
# images processed: 6
# Fooled z:
# 7
# Fooled s:
# 5
# images processed: 7
# Fooled z:
# 8
# Fooled s:
# 5
# images processed: 8
# Fooled z:
# 8
# Fooled s:
# 6
# images processed: 9
# Fooled z:
# 9
# Fooled s:
# 6
# images processed: 10
# Fooled z %:
# 90.0
# Fooled s %:
# 60.0
# Confused z %:
# 100.0
# Confused s %:
# 100.0

# %%
images_used = []
targets = []
fooled_s = []
fooled_z = [] 
confused_z = []
confused_s = []

while len(images_used) < 100:
    
    random_int = np.random.randint(50000)
    if random_int in images_used:
        continue
    im = Image.open(fnames[random_int]).convert('RGB')
    true_label = y_val[random_int]
    
    pred_z = predict(z, im, False)
    label_z = np.argmax(pred_z)
    if true_label != label_z or pred_z[label_z] < 0.5:
        continue
    pred_s = predict(s, im, False)
    label_s = np.argmax(pred_s)
    if true_label != label_s or pred_s[label_s] < 0.5:
        continue
    #images are correctly recognized before attacks
    images_used.append(random_int)
    
    target = random_exclude(1000, [true_label])
    targets.append(target)
    
    adv_z = perform_attack(im, 'z', target, True, show_info=False)
    adv_s = perform_attack(im, 's', target, True, show_info=False)
    
    adv_class_z = np.argmax(adv_z)
    adv_class_s = np.argmax(adv_s)
    
    fooled_z.append(target == adv_class_z and adv_z[adv_class_z] >= 0.5)
    fooled_s.append(target == adv_class_s and adv_s[adv_class_s] >= 0.5)
    confused_z.append(adv_class_z != true_label)
    confused_s.append(adv_class_s != true_label)
    
    print('Fooled z:')
    print(np.array(fooled_z).sum())
    print('Fooled s:')
    print(np.array(fooled_s).sum())
    print(f'images processed: {len(images_used)}')

print('Fooled z %:')
print(np.array(fooled_z).sum() / len(images_used) * 100)
print('Fooled s %:')
print(np.array(fooled_s).sum() / len(images_used) * 100)


print('Confused z %:')
print(np.array(confused_z).sum() / len(images_used) * 100)
print('Confused s %:')
print(np.array(confused_s).sum() / len(images_used) * 100)
# Out:
# Fooled z:
# 1
# Fooled s:
# 1
# images processed: 1
# Fooled z:
# 2
# Fooled s:
# 2
# images processed: 2
# Fooled z:
# 3
# Fooled s:
# 3
# images processed: 3
# Fooled z:
# 4
# Fooled s:
# 4
# images processed: 4
# Fooled z:
# 5
# Fooled s:
# 5
# images processed: 5
# Fooled z:
# 6
# Fooled s:
# 6
# images processed: 6
# Fooled z:
# 7
# Fooled s:
# 7
# images processed: 7
# Fooled z:
# 8
# Fooled s:
# 8
# images processed: 8
# Fooled z:
# 9
# Fooled s:
# 9
# images processed: 9
# Fooled z:
# 10
# Fooled s:
# 10
# images processed: 10
# Fooled z:
# 11
# Fooled s:
# 10
# images processed: 11
# Fooled z:
# 12
# Fooled s:
# 11
# images processed: 12
# Fooled z:
# 13
# Fooled s:
# 12
# images processed: 13
# Fooled z:
# 14
# Fooled s:
# 13
# images processed: 14
# Fooled z:
# 15
# Fooled s:
# 14
# images processed: 15
# Fooled z:
# 16
# Fooled s:
# 15
# images processed: 16
# Fooled z:
# 17
# Fooled s:
# 16
# images processed: 17
# Fooled z:
# 18
# Fooled s:
# 17
# images processed: 18
# Fooled z:
# 19
# Fooled s:
# 18
# images processed: 19
# Fooled z:
# 20
# Fooled s:
# 19
# images processed: 20
# Fooled z:
# 21
# Fooled s:
# 20
# images processed: 21
# Fooled z:
# 22
# Fooled s:
# 21
# images processed: 22
# Fooled z:
# 23
# Fooled s:
# 22
# images processed: 23
# Fooled z:
# 24
# Fooled s:
# 23
# images processed: 24
# Fooled z:
# 25
# Fooled s:
# 24
# images processed: 25
# Fooled z:
# 26
# Fooled s:
# 25
# images processed: 26
# Fooled z:
# 27
# Fooled s:
# 26
# images processed: 27
# Fooled z:
# 28
# Fooled s:
# 26
# images processed: 28
# Fooled z:
# 29
# Fooled s:
# 27
# images processed: 29
# Fooled z:
# 30
# Fooled s:
# 28
# images processed: 30
# Fooled z:
# 30
# Fooled s:
# 28
# images processed: 31
# Fooled z:
# 31
# Fooled s:
# 28
# images processed: 32
# Fooled z:
# 32
# Fooled s:
# 29
# images processed: 33
# Fooled z:
# 33
# Fooled s:
# 30
# images processed: 34
# Fooled z:
# 34
# Fooled s:
# 31
# images processed: 35
# Fooled z:
# 35
# Fooled s:
# 32
# images processed: 36
# Fooled z:
# 36
# Fooled s:
# 33
# images processed: 37
# Fooled z:
# 37
# Fooled s:
# 34
# images processed: 38
# Fooled z:
# 38
# Fooled s:
# 35
# images processed: 39
# Fooled z:
# 39
# Fooled s:
# 35
# images processed: 40
# Fooled z:
# 40
# Fooled s:
# 36
# images processed: 41
# Fooled z:
# 41
# Fooled s:
# 37
# images processed: 42
# Fooled z:
# 42
# Fooled s:
# 37
# images processed: 43
# Fooled z:
# 43
# Fooled s:
# 38
# images processed: 44
# Fooled z:
# 44
# Fooled s:
# 39
# images processed: 45
# Fooled z:
# 45
# Fooled s:
# 40
# images processed: 46
# Fooled z:
# 46
# Fooled s:
# 41
# images processed: 47
# Fooled z:
# 47
# Fooled s:
# 42
# images processed: 48
# Fooled z:
# 48
# Fooled s:
# 43
# images processed: 49
# Fooled z:
# 49
# Fooled s:
# 44
# images processed: 50
# Fooled z:
# 50
# Fooled s:
# 44
# images processed: 51
# Fooled z:
# 51
# Fooled s:
# 45
# images processed: 52
# Fooled z:
# 52
# Fooled s:
# 46
# images processed: 53
# Fooled z:
# 53
# Fooled s:
# 47
# images processed: 54
# Fooled z:
# 54
# Fooled s:
# 48
# images processed: 55
# Fooled z:
# 55
# Fooled s:
# 49
# images processed: 56
# Fooled z:
# 56
# Fooled s:
# 50
# images processed: 57
# Fooled z:
# 57
# Fooled s:
# 51
# images processed: 58
# Fooled z:
# 58
# Fooled s:
# 52
# images processed: 59
# Fooled z:
# 59
# Fooled s:
# 53
# images processed: 60
# Fooled z:
# 60
# Fooled s:
# 54
# images processed: 61
# Fooled z:
# 61
# Fooled s:
# 54
# images processed: 62
# Fooled z:
# 62
# Fooled s:
# 54
# images processed: 63
# Fooled z:
# 63
# Fooled s:
# 55
# images processed: 64
# Fooled z:
# 64
# Fooled s:
# 55
# images processed: 65
# Fooled z:
# 65
# Fooled s:
# 56
# images processed: 66
# Fooled z:
# 66
# Fooled s:
# 57
# images processed: 67
# Fooled z:
# 67
# Fooled s:
# 58
# images processed: 68
# Fooled z:
# 68
# Fooled s:
# 59
# images processed: 69
# Fooled z:
# 69
# Fooled s:
# 60
# images processed: 70
# Fooled z:
# 70
# Fooled s:
# 61
# images processed: 71
# Fooled z:
# 71
# Fooled s:
# 61
# images processed: 72
# Fooled z:
# 72
# Fooled s:
# 62
# images processed: 73
# Fooled z:
# 73
# Fooled s:
# 63
# images processed: 74
# Fooled z:
# 74
# Fooled s:
# 64
# images processed: 75
# Fooled z:
# 75
# Fooled s:
# 64
# images processed: 76
# Fooled z:
# 76
# Fooled s:
# 65
# images processed: 77
# Fooled z:
# 77
# Fooled s:
# 66
# images processed: 78
# Fooled z:
# 78
# Fooled s:
# 67
# images processed: 79
# Fooled z:
# 79
# Fooled s:
# 68
# images processed: 80
# Fooled z:
# 80
# Fooled s:
# 69
# images processed: 81
# Fooled z:
# 81
# Fooled s:
# 70
# images processed: 82
# Fooled z:
# 82
# Fooled s:
# 71
# images processed: 83
# Fooled z:
# 83
# Fooled s:
# 72
# images processed: 84
# Fooled z:
# 84
# Fooled s:
# 72
# images processed: 85
# Fooled z:
# 85
# Fooled s:
# 73
# images processed: 86
# Fooled z:
# 86
# Fooled s:
# 73
# images processed: 87
# Fooled z:
# 87
# Fooled s:
# 74
# images processed: 88
# Fooled z:
# 88
# Fooled s:
# 75
# images processed: 89
# Fooled z:
# 89
# Fooled s:
# 76
# images processed: 90
# Fooled z:
# 90
# Fooled s:
# 76
# images processed: 91
# Fooled z:
# 91
# Fooled s:
# 77
# images processed: 92
# Fooled z:
# 92
# Fooled s:
# 77
# images processed: 93
# Fooled z:
# 93
# Fooled s:
# 78
# images processed: 94
# Fooled z:
# 94
# Fooled s:
# 79
# images processed: 95
# Fooled z:
# 95
# Fooled s:
# 80
# images processed: 96
# Fooled z:
# 96
# Fooled s:
# 81
# images processed: 97
# Fooled z:
# 97
# Fooled s:
# 82
# images processed: 98
# Fooled z:
# 98
# Fooled s:
# 83
# images processed: 99
# Fooled z:
# 99
# Fooled s:
# 84
# images processed: 100
# Fooled z %:
# 99.0
# Fooled s %:
# 84.0
# Confused z %:
# 100.0
# Confused s %:
# 99.0
