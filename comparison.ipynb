# %%
import os
import argparse
import time
import glob
import pickle
import subprocess
import shlex
import io
import pprint
import importlib
from urllib.request import urlopen
from IPython.display import Image as dispImg
import scipy.io
import numpy as np
import pandas
import tqdm
import fire
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.utils.model_zoo
import torchvision
from art.classifiers import PyTorchClassifier
import cornet
from art.attacks import BoundaryAttack
from art.attacks import HopSkipJump
from imgaug import augmenters as iaa
import imgaug as ia
#attack = HopSkipJump(classifier=classifier, targeted=False, max_iter=0, max_eval=1000, init_eval=10)
from art.attacks import FastGradientMethod
from art.attacks import ElasticNet

from PIL import Image
Image.warnings.simplefilter('ignore')

ia.seed(1)
np.random.seed(0)
torch.manual_seed(0)

mean = torch.tensor([0.44, 0.44, 0.44], dtype=torch.float32)
std = torch.tensor([0.225, 0.225, 0.225], dtype=torch.float32)
normalize = torchvision.transforms.Normalize(mean=[0.44, 0.44, 0.44],
                                             std=[0.225, 0.225, 0.225])
transform = torchvision.transforms.Compose([
                torchvision.transforms.Resize(256),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                normalize
            ])
unnormalize = torchvision.transforms.Normalize((-mean / std).tolist(), (1.0 / std).tolist())

def get_model(model_size='z', cuda=False):
    map_location = 'cpu' if not cuda else None
    #map_location = None
    model = getattr(cornet, f'cornet_{model_size.lower()}')
    if model_size.lower() == 'r':
        model = model(pretrained=True, map_location=map_location, times=5)
    else:
        model = model(pretrained=True, map_location=map_location)
    if cuda:
        model = model.cuda()
        return model
    model.cpu()
    return model.module

sharpen = iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5), deterministic=True)


                # Same as sharpen, but for an embossing effect.
emboss = iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0), deterministic=True)

# %% [markdown]
# Load data

# %%
labels = pickle.load(open("labels.pkl", "rb" ))
y_val = np.load("D:\\imagenet2012\\y_val.npy")
print(f"{y_val.shape[0]} validation labels loaded")
data_path = 'D:\\imagenet2012\\val'
fnames = sorted(glob.glob(os.path.join(data_path, '*.*')))
print(f"{len(fnames)} files found");
# Out:
# 50000 validation labels loaded
# 50000 files found

# %%
def to_grayscale(img):
    return np.dot(img[...,:3], [0.299, 0.587, 0.114])

# %%
np.argsort((y_val == 26))[-2]
# Out:
# 48045

# %%
def get_image_by_class(image_class):
    return Image.open(fnames[np.argsort((y_val == image_class))[-1]]).convert('RGB')

# %%
def plot_augmented(original_image, adv_image):
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 16))
    axes[0, 0].imshow(to_grayscale(original_image))
    axes[0, 1].imshow(to_grayscale(adv_image))
    axes[1, 0].imshow(to_grayscale(sharpen.augment_image(original_image)))
    axes[1, 1].imshow(to_grayscale(sharpen.augment_image(adv_image)))
    axes[2, 0].imshow(to_grayscale(emboss.augment_image(original_image)))
    axes[2, 1].imshow(to_grayscale(emboss.augment_image(adv_image)))
    plt.show()

# %%
def l2(orig, adv):
    return np.linalg.norm(np.reshape(adv[0] - orig[0], [-1]))

# %%
def perform_attack(im, model_size, target_class=None, targeted=False, eps=0.3, show_info=True):
    model = get_model(model_size)
    model.eval()
    if show_info:
        print(f'using model type: {model_size}')
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


    classifier = PyTorchClassifier(model=model, loss=criterion,
                               optimizer=optimizer, nb_classes=1000, input_shape=(3,224,224), clip_values=(-1.956, 6.4))
    attack = FastGradientMethod(classifier=classifier, eps=eps, targeted=targeted, minimal=True)
    
    x = transform(im).unsqueeze(0).numpy()
    
    pred = classifier.predict(x)[0]
    pred = np.exp(pred)/sum(np.exp(pred))
    if show_info:
        top_5 = np.flip(np.argsort(pred)[-5:])
        print('\nOriginal image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {pred[t]}')
        print('\nGenerating adversarial example')
    
    x_adv = attack.generate(x=transform(im).unsqueeze(0).numpy(), y=np.array([target_class]) if target_class is not None else None)
    if show_info:
        print('L2: ' + str(np.linalg.norm(np.reshape(x_adv[0] - x[0], [-1]))))
    
    original_image = np.moveaxis(unnormalize(torch.from_numpy(x[0])).numpy(),  [0, 1, 2], [2, 0, 1])
    adv_image = np.moveaxis(unnormalize(torch.from_numpy(x_adv[0])).numpy(),  [0, 1, 2], [2, 0, 1])
    pert = np.abs(adv_image - original_image)[..., ::-1]
    pert_min = np.min(pert)
    pert_max = np.max(pert)
    pert_image = -((pert - pert_min) / (pert_max - pert_min))+1
    if show_info:
        fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 16))
        axes[0].imshow(original_image)
        axes[1].imshow(pert_image)
        axes[2].imshow(adv_image)
    
    adv_pred = classifier.predict(x_adv)[0]
    adv_pred = np.exp(adv_pred)/sum(np.exp(adv_pred))
    if show_info:
        top_5 = np.flip(np.argsort(adv_pred)[-5:])
        print('\nAdversarial image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {adv_pred[t]}')
    
    plt.show()
    return adv_pred

# %%
i=39218
print(labels[y_val[i]])
#target 39206
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a308d4f5196> in <module>
#       1 i=39218
# ----> 2 print(labels[y_val[i]])
#       3 #target 39206
#
# NameError: name 'labels' is not defined

# %%
#im = Image.open(fnames[i]).convert('RGB')
#im = Image.open("D:\\imagenet2012\junco.jpg").convert('RGB')
im = Image.open("D:\\imagenet2012\john_cleese.png").convert('RGB')
#im = Image.open(fnames[np.argsort((y_val == 26))[-3]]).convert('RGB')
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bd0f9e844ee8> in <module>
#       1 #im = Image.open(fnames[i]).convert('RGB')
#       2 #im = Image.open("D:\\imagenet2012\junco.jpg").convert('RGB')
# ----> 3 im = Image.open("D:\\imagenet2012\john_cleese.png").convert('RGB')
#       4 #im = Image.open(fnames[np.argsort((y_val == 26))[-3]]).convert('RGB')
#       5 im
#
# NameError: name 'Image' is not defined

# %%
def get_classifier(model_size='z'):
    model = get_model(model_size)
    model.eval()
    print(f'using model type: {model_size}')

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


    classifier = PyTorchClassifier(model=model, loss=criterion,
                                   optimizer=optimizer, nb_classes=1000, input_shape=(3,224,224), clip_values=(-1.956, 6.4))
    return classifier

# %%
z = get_classifier()
s = get_classifier('s')
# Out:
# using model type: z
# using model type: s

# %%
def predict(classifier, im, show_info=True):

    x = transform(im).unsqueeze(0).numpy()

    pred = classifier.predict(x)[0]
    pred = np.exp(pred)/sum(np.exp(pred))
    if show_info:
        top_5 = np.flip(np.argsort(pred)[-5:])
        print('\nOriginal image predictions:')
        for t in top_5:
            print(f'{labels[t]} ({t}): {pred[t]}')

            plt.imshow(np.moveaxis(unnormalize(torch.from_numpy(x[0])).numpy(),  [0, 1, 2], [2, 0, 1]))
            plt.show()
    return pred

# %%
def random_exclude(high, exclude=[]):
    tries_left = 5
    while tries_left > 1:
        num = np.random.randint(high)
        tries_left -= 1
        if num not in exclude:
            return num
    raise Exception('Could not generate random number')

# %%
images_used = []
targets = []
fooled_s = []
fooled_z = [] 
confused_z = []
confused_s = []

while len(images_used) < 1000:
    
    random_int = np.random.randint(50000)
    if random_int in images_used:
        continue
    im = Image.open(fnames[random_int]).convert('RGB')
    true_label = y_val[random_int]
    
    pred_z = predict(z, im, False)
    label_z = np.argmax(pred_z)
    if true_label != label_z or pred_z[label_z] < 0.5:
        continue
    pred_s = predict(s, im, False)
    label_s = np.argmax(pred_s)
    if true_label != label_s or pred_s[label_s] < 0.5:
        continue
    #images are correctly recognized before attacks
    images_used.append(random_int)
    
    target = random_exclude(1000, [true_label])
    targets.append(target)
    
    adv_z = perform_attack(im, 'z', target, True, show_info=False)
    adv_s = perform_attack(im, 's', target, True, show_info=False)
    
    adv_class_z = np.argmax(adv_z)
    adv_class_s = np.argmax(adv_s)
    
    fooled_z.append(target == adv_class_z and adv_z[adv_class_z] >= 0.5)
    fooled_s.append(target == adv_class_s and adv_s[adv_class_s] >= 0.5)
    confused_z.append(adv_class_z != true_label)
    confused_s.append(adv_class_s != true_label)
    
    print('Fooled z:')
    print(np.array(fooled_z).sum())
    print('Fooled s:')
    print(np.array(fooled_s).sum())
    print(f'images processed: {len(images_used)}')

print('Fooled z %:')
print(np.array(fooled_z).sum() / len(images_used) * 100)
print('Fooled s %:')
print(np.array(fooled_s).sum() / len(images_used) * 100)


print('Confused z %:')
print(np.array(confused_z).sum() / len(images_used) * 100)
print('Confused s %:')
print(np.array(confused_s).sum() / len(images_used) * 100)
# Out:
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 1
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 2
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 3
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 4
# Fooled z:
# 0
# Fooled s:
# 0
# images processed: 5
# Fooled z:
# 1
# Fooled s:
# 0
# images processed: 6
# Fooled z:
# 1
# Fooled s:
# 0
# images processed: 7
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 8
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 9
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 10
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 11
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 12
# Fooled z:
# 2
# Fooled s:
# 0
# images processed: 13
# Fooled z:
# 3
# Fooled s:
# 0
# images processed: 14
# Fooled z:
# 3
# Fooled s:
# 0
# images processed: 15
# Fooled z:
# 3
# Fooled s:
# 0
# images processed: 16
# Fooled z:
# 4
# Fooled s:
# 0
# images processed: 17
# Fooled z:
# 5
# Fooled s:
# 0
# images processed: 18
# Fooled z:
# 5
# Fooled s:
# 0
# images processed: 19
# Fooled z:
# 5
# Fooled s:
# 0
# images processed: 20
# Fooled z:
# 5
# Fooled s:
# 1
# images processed: 21
# Fooled z:
# 5
# Fooled s:
# 1
# images processed: 22
# Fooled z:
# 5
# Fooled s:
# 1
# images processed: 23
# Fooled z:
# 5
# Fooled s:
# 1
# images processed: 24
# Fooled z:
# 5
# Fooled s:
# 1
# images processed: 25
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 26
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 27
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 28
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 29
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 30
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 31
# Fooled z:
# 6
# Fooled s:
# 1
# images processed: 32
# Fooled z:
# 7
# Fooled s:
# 1
# images processed: 33
# Fooled z:
# 7
# Fooled s:
# 1
# images processed: 34
# Fooled z:
# 7
# Fooled s:
# 1
# images processed: 35
# Fooled z:
# 7
# Fooled s:
# 1
# images processed: 36
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 37
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 38
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 39
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 40
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 41
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 42
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 43
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 44
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 45
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 46
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 47
# Fooled z:
# 8
# Fooled s:
# 1
# images processed: 48
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 49
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 50
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 51
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 52
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 53
# Fooled z:
# 9
# Fooled s:
# 1
# images processed: 54
# Fooled z:
# 10
# Fooled s:
# 1
# images processed: 55
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 56
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 57
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 58
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 59
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 60
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 61
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 62
# Fooled z:
# 11
# Fooled s:
# 1
# images processed: 63
# Fooled z:
# 12
# Fooled s:
# 1
# images processed: 64
# Fooled z:
# 12
# Fooled s:
# 1
# images processed: 65
# Fooled z:
# 12
# Fooled s:
# 1
# images processed: 66
# Fooled z:
# 12
# Fooled s:
# 1
# images processed: 67
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 68
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 69
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 70
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 71
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 72
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 73
# Fooled z:
# 13
# Fooled s:
# 1
# images processed: 74
# Fooled z:
# 14
# Fooled s:
# 2
# images processed: 75
# Fooled z:
# 14
# Fooled s:
# 2
# images processed: 76
# Fooled z:
# 14
# Fooled s:
# 2
# images processed: 77
# Fooled z:
# 14
# Fooled s:
# 2
# images processed: 78
# Fooled z:
# 15
# Fooled s:
# 2
# images processed: 79
# Fooled z:
# 16
# Fooled s:
# 2
# images processed: 80
# Fooled z:
# 16
# Fooled s:
# 2
# images processed: 81
# Fooled z:
# 16
# Fooled s:
# 2
# images processed: 82
# Fooled z:
# 16
# Fooled s:
# 2
# images processed: 83
# Fooled z:
# 16
# Fooled s:
# 2
# images processed: 84
# Fooled z:
# 17
# Fooled s:
# 2
# images processed: 85
# Fooled z:
# 18
# Fooled s:
# 2
# images processed: 86
# Fooled z:
# 19
# Fooled s:
# 2
# images processed: 87
# Fooled z:
# 20
# Fooled s:
# 2
# images processed: 88
# Fooled z:
# 21
# Fooled s:
# 2
# images processed: 89
# Fooled z:
# 22
# Fooled s:
# 2
# images processed: 90
# Fooled z:
# 22
# Fooled s:
# 2
# images processed: 91
# Fooled z:
# 23
# Fooled s:
# 2
# images processed: 92
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 93
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 94
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 95
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 96
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 97
# Fooled z:
# 24
# Fooled s:
# 2
# images processed: 98
# Fooled z:
# 25
# Fooled s:
# 2
# images processed: 99
# Fooled z:
# 26
# Fooled s:
# 2
# images processed: 100
# Fooled z:
# 26
# Fooled s:
# 2
# images processed: 101
# Fooled z:
# 26
# Fooled s:
# 2
# images processed: 102
# Fooled z:
# 26
# Fooled s:
# 2
# images processed: 103
# Fooled z:
# 27
# Fooled s:
# 2
# images processed: 104
# Fooled z:
# 27
# Fooled s:
# 2
# images processed: 105
# Fooled z:
# 28
# Fooled s:
# 2
# images processed: 106
# Fooled z:
# 29
# Fooled s:
# 2
# images processed: 107
# Fooled z:
# 29
# Fooled s:
# 2
# images processed: 108
# Fooled z:
# 29
# Fooled s:
# 2
# images processed: 109
# Fooled z:
# 29
# Fooled s:
# 2
# images processed: 110
# Fooled z:
# 29
# Fooled s:
# 2
# images processed: 111
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 112
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 113
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 114
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 115
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 116
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 117
# Fooled z:
# 30
# Fooled s:
# 2
# images processed: 118
# Fooled z:
# 31
# Fooled s:
# 2
# images processed: 119
# Fooled z:
# 31
# Fooled s:
# 2
# images processed: 120
# Fooled z:
# 31
# Fooled s:
# 2
# images processed: 121
# Fooled z:
# 32
# Fooled s:
# 2
# images processed: 122
# Fooled z:
# 33
# Fooled s:
# 2
# images processed: 123
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 124
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 125
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 126
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 127
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 128
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 129
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 130
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 131
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 132
# Fooled z:
# 34
# Fooled s:
# 2
# images processed: 133
# Fooled z:
# 35
# Fooled s:
# 2
# images processed: 134
# Fooled z:
# 35
# Fooled s:
# 2
# images processed: 135
# Fooled z:
# 36
# Fooled s:
# 2
# images processed: 136
# Fooled z:
# 37
# Fooled s:
# 2
# images processed: 137
# Fooled z:
# 37
# Fooled s:
# 2
# images processed: 138
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 139
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 140
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 141
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 142
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 143
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 144
# Fooled z:
# 38
# Fooled s:
# 2
# images processed: 145
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 146
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 147
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 148
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 149
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 150
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 151
# Fooled z:
# 39
# Fooled s:
# 2
# images processed: 152
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 153
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 154
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 155
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 156
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 157
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 158
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 159
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 160
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 161
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 162
# Fooled z:
# 40
# Fooled s:
# 2
# images processed: 163
# Fooled z:
# 41
# Fooled s:
# 2
# images processed: 164
# Fooled z:
# 41
# Fooled s:
# 2
# images processed: 165
# Fooled z:
# 41
# Fooled s:
# 2
# images processed: 166
# Fooled z:
# 42
# Fooled s:
# 2
# images processed: 167
# Fooled z:
# 42
# Fooled s:
# 2
# images processed: 168
# Fooled z:
# 43
# Fooled s:
# 2
# images processed: 169
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 170
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 171
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 172
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 173
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 174
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 175
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 176
# Fooled z:
# 44
# Fooled s:
# 2
# images processed: 177
# Fooled z:
# 45
# Fooled s:
# 2
# images processed: 178
# Fooled z:
# 45
# Fooled s:
# 2
# images processed: 179
# Fooled z:
# 46
# Fooled s:
# 2
# images processed: 180
# Fooled z:
# 46
# Fooled s:
# 2
# images processed: 181
# Fooled z:
# 46
# Fooled s:
# 2
# images processed: 182
# Fooled z:
# 46
# Fooled s:
# 2
# images processed: 183
# Fooled z:
# 47
# Fooled s:
# 2
# images processed: 184
# Fooled z:
# 47
# Fooled s:
# 2
# images processed: 185
# Fooled z:
# 47
# Fooled s:
# 2
# images processed: 186
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 187
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 188
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 189
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 190
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 191
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 192
# Fooled z:
# 48
# Fooled s:
# 2
# images processed: 193
# Fooled z:
# 49
# Fooled s:
# 2
# images processed: 194
# Fooled z:
# 49
# Fooled s:
# 2
# images processed: 195
# Fooled z:
# 50
# Fooled s:
# 2
# images processed: 196
# Fooled z:
# 50
# Fooled s:
# 2
# images processed: 197
# Fooled z:
# 51
# Fooled s:
# 2
# images processed: 198
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 199
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 200
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 201
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 202
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 203
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 204
# Fooled z:
# 52
# Fooled s:
# 2
# images processed: 205
# Fooled z:
# 53
# Fooled s:
# 2
# images processed: 206
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 207
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 208
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 209
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 210
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 211
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 212
# Fooled z:
# 54
# Fooled s:
# 3
# images processed: 213
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 214
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 215
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 216
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 217
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 218
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 219
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 220
# Fooled z:
# 55
# Fooled s:
# 3
# images processed: 221
# Fooled z:
# 56
# Fooled s:
# 3
# images processed: 222
# Fooled z:
# 56
# Fooled s:
# 3
# images processed: 223
# Fooled z:
# 56
# Fooled s:
# 3
# images processed: 224
# Fooled z:
# 56
# Fooled s:
# 3
# images processed: 225
# Fooled z:
# 56
# Fooled s:
# 3
# images processed: 226
# Fooled z:
# 57
# Fooled s:
# 3
# images processed: 227
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 228
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 229
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 230
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 231
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 232
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 233
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 234
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 235
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 236
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 237
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 238
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 239
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 240
# Fooled z:
# 58
# Fooled s:
# 3
# images processed: 241
# Fooled z:
# 59
# Fooled s:
# 3
# images processed: 242
# Fooled z:
# 59
# Fooled s:
# 3
# images processed: 243
# Fooled z:
# 60
# Fooled s:
# 3
# images processed: 244
# Fooled z:
# 60
# Fooled s:
# 3
# images processed: 245
# Fooled z:
# 60
# Fooled s:
# 3
# images processed: 246
# Fooled z:
# 60
# Fooled s:
# 3
# images processed: 247
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 248
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 249
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 250
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 251
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 252
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 253
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 254
# Fooled z:
# 61
# Fooled s:
# 3
# images processed: 255
# Fooled z:
# 62
# Fooled s:
# 3
# images processed: 256
# Fooled z:
# 63
# Fooled s:
# 3
# images processed: 257
# Fooled z:
# 63
# Fooled s:
# 3
# images processed: 258
# Fooled z:
# 63
# Fooled s:
# 3
# images processed: 259
# Fooled z:
# 63
# Fooled s:
# 3
# images processed: 260
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 261
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 262
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 263
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 264
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 265
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 266
# Fooled z:
# 64
# Fooled s:
# 3
# images processed: 267
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 268
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 269
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 270
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 271
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 272
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 273
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 274
# Fooled z:
# 65
# Fooled s:
# 3
# images processed: 275
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 276
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 277
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 278
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 279
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 280
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 281
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 282
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 283
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 284
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 285
# Fooled z:
# 66
# Fooled s:
# 3
# images processed: 286
# Fooled z:
# 67
# Fooled s:
# 3
# images processed: 287
# Fooled z:
# 67
# Fooled s:
# 3
# images processed: 288
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 289
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 290
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 291
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 292
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 293
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 294
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 295
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 296
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 297
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 298
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 299
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 300
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 301
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 302
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 303
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 304
# Fooled z:
# 68
# Fooled s:
# 3
# images processed: 305
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 306
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 307
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 308
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 309
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 310
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 311
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 312
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 313
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 314
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 315
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 316
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 317
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 318
# Fooled z:
# 69
# Fooled s:
# 3
# images processed: 319
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 320
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 321
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 322
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 323
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 324
# Fooled z:
# 70
# Fooled s:
# 4
# images processed: 325
# Fooled z:
# 71
# Fooled s:
# 4
# images processed: 326
# Fooled z:
# 72
# Fooled s:
# 4
# images processed: 327
# Fooled z:
# 72
# Fooled s:
# 4
# images processed: 328
# Fooled z:
# 72
# Fooled s:
# 4
# images processed: 329
# Fooled z:
# 72
# Fooled s:
# 4
# images processed: 330
# Fooled z:
# 73
# Fooled s:
# 4
# images processed: 331
# Fooled z:
# 73
# Fooled s:
# 4
# images processed: 332
# Fooled z:
# 74
# Fooled s:
# 4
# images processed: 333
# Fooled z:
# 74
# Fooled s:
# 4
# images processed: 334
# Fooled z:
# 75
# Fooled s:
# 4
# images processed: 335
# Fooled z:
# 75
# Fooled s:
# 4
# images processed: 336
# Fooled z:
# 75
# Fooled s:
# 4
# images processed: 337
# Fooled z:
# 76
# Fooled s:
# 4
# images processed: 338
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 339
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 340
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 341
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 342
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 343
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 344
# Fooled z:
# 77
# Fooled s:
# 4
# images processed: 345
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 346
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 347
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 348
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 349
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 350
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 351
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 352
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 353
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 354
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 355
# Fooled z:
# 78
# Fooled s:
# 4
# images processed: 356
# Fooled z:
# 79
# Fooled s:
# 4
# images processed: 357
# Fooled z:
# 79
# Fooled s:
# 4
# images processed: 358
# Fooled z:
# 79
# Fooled s:
# 4
# images processed: 359
# Fooled z:
# 79
# Fooled s:
# 4
# images processed: 360
# Fooled z:
# 79
# Fooled s:
# 4
# images processed: 361
# Fooled z:
# 80
# Fooled s:
# 4
# images processed: 362
# Fooled z:
# 80
# Fooled s:
# 4
# images processed: 363
# Fooled z:
# 81
# Fooled s:
# 4
# images processed: 364
# Fooled z:
# 81
# Fooled s:
# 4
# images processed: 365
# Fooled z:
# 81
# Fooled s:
# 4
# images processed: 366
# Fooled z:
# 81
# Fooled s:
# 4
# images processed: 367
# Fooled z:
# 81
# Fooled s:
# 4
# images processed: 368
# Fooled z:
# 82
# Fooled s:
# 4
# images processed: 369
# Fooled z:
# 82
# Fooled s:
# 4
# images processed: 370
# Fooled z:
# 82
# Fooled s:
# 4
# images processed: 371
# Fooled z:
# 82
# Fooled s:
# 4
# images processed: 372
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 373
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 374
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 375
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 376
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 377
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 378
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 379
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 380
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 381
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 382
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 383
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 384
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 385
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 386
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 387
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 388
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 389
# Fooled z:
# 83
# Fooled s:
# 4
# images processed: 390
# Fooled z:
# 84
# Fooled s:
# 4
# images processed: 391
# Fooled z:
# 85
# Fooled s:
# 4
# images processed: 392
# Fooled z:
# 85
# Fooled s:
# 4
# images processed: 393
# Fooled z:
# 85
# Fooled s:
# 4
# images processed: 394
# Fooled z:
# 85
# Fooled s:
# 4
# images processed: 395
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 396
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 397
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 398
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 399
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 400
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 401
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 402
# Fooled z:
# 86
# Fooled s:
# 4
# images processed: 403
# Fooled z:
# 87
# Fooled s:
# 4
# images processed: 404
# Fooled z:
# 87
# Fooled s:
# 4
# images processed: 405
# Fooled z:
# 87
# Fooled s:
# 4
# images processed: 406
# Fooled z:
# 88
# Fooled s:
# 4
# images processed: 407
# Fooled z:
# 88
# Fooled s:
# 4
# images processed: 408
# Fooled z:
# 88
# Fooled s:
# 4
# images processed: 409
# Fooled z:
# 88
# Fooled s:
# 4
# images processed: 410
# Fooled z:
# 89
# Fooled s:
# 4
# images processed: 411
# Fooled z:
# 90
# Fooled s:
# 4
# images processed: 412
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 413
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 414
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 415
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 416
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 417
# Fooled z:
# 91
# Fooled s:
# 4
# images processed: 418
# Fooled z:
# 92
# Fooled s:
# 4
# images processed: 419
# Fooled z:
# 93
# Fooled s:
# 4
# images processed: 420
# Fooled z:
# 93
# Fooled s:
# 4
# images processed: 421
# Fooled z:
# 93
# Fooled s:
# 4
# images processed: 422
# Fooled z:
# 93
# Fooled s:
# 4
# images processed: 423
# Fooled z:
# 93
# Fooled s:
# 4
# images processed: 424
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 425
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 426
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 427
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 428
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 429
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 430
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 431
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 432
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 433
# Fooled z:
# 94
# Fooled s:
# 4
# images processed: 434
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 435
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 436
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 437
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 438
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 439
# Fooled z:
# 95
# Fooled s:
# 4
# images processed: 440
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 441
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 442
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 443
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 444
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 445
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 446
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 447
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 448
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 449
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 450
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 451
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 452
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 453
# Fooled z:
# 96
# Fooled s:
# 4
# images processed: 454
# Fooled z:
# 97
# Fooled s:
# 4
# images processed: 455
# Fooled z:
# 98
# Fooled s:
# 4
# images processed: 456
# Fooled z:
# 98
# Fooled s:
# 4
# images processed: 457
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 458
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 459
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 460
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 461
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 462
# Fooled z:
# 99
# Fooled s:
# 4
# images processed: 463
# Fooled z:
# 100
# Fooled s:
# 4
# images processed: 464
# Fooled z:
# 100
# Fooled s:
# 4
# images processed: 465
# Fooled z:
# 101
# Fooled s:
# 4
# images processed: 466
# Fooled z:
# 102
# Fooled s:
# 4
# images processed: 467
# Fooled z:
# 102
# Fooled s:
# 4
# images processed: 468
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 469
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 470
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 471
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 472
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 473
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 474
# Fooled z:
# 103
# Fooled s:
# 4
# images processed: 475
# Fooled z:
# 104
# Fooled s:
# 4
# images processed: 476
# Fooled z:
# 104
# Fooled s:
# 4
# images processed: 477
# Fooled z:
# 104
# Fooled s:
# 4
# images processed: 478
# Fooled z:
# 104
# Fooled s:
# 4
# images processed: 479
# Fooled z:
# 105
# Fooled s:
# 4
# images processed: 480
# Fooled z:
# 105
# Fooled s:
# 4
# images processed: 481
# Fooled z:
# 106
# Fooled s:
# 4
# images processed: 482
# Fooled z:
# 106
# Fooled s:
# 4
# images processed: 483
# Fooled z:
# 107
# Fooled s:
# 4
# images processed: 484
# Fooled z:
# 107
# Fooled s:
# 4
# images processed: 485
# Fooled z:
# 107
# Fooled s:
# 4
# images processed: 486
# Fooled z:
# 108
# Fooled s:
# 4
# images processed: 487
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 488
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 489
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 490
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 491
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 492
# Fooled z:
# 109
# Fooled s:
# 4
# images processed: 493
# Fooled z:
# 110
# Fooled s:
# 4
# images processed: 494
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 495
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 496
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 497
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 498
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 499
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 500
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 501
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 502
# Fooled z:
# 111
# Fooled s:
# 5
# images processed: 503
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 504
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 505
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 506
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 507
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 508
# Fooled z:
# 112
# Fooled s:
# 5
# images processed: 509
# Fooled z:
# 113
# Fooled s:
# 5
# images processed: 510
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 511
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 512
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 513
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 514
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 515
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 516
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 517
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 518
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 519
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 520
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 521
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 522
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 523
# Fooled z:
# 114
# Fooled s:
# 5
# images processed: 524
# Fooled z:
# 115
# Fooled s:
# 5
# images processed: 525
# Fooled z:
# 115
# Fooled s:
# 5
# images processed: 526
# Fooled z:
# 115
# Fooled s:
# 5
# images processed: 527
# Fooled z:
# 115
# Fooled s:
# 5
# images processed: 528
# Fooled z:
# 115
# Fooled s:
# 5
# images processed: 529
# Fooled z:
# 116
# Fooled s:
# 5
# images processed: 530
# Fooled z:
# 117
# Fooled s:
# 5
# images processed: 531
# Fooled z:
# 117
# Fooled s:
# 5
# images processed: 532
# Fooled z:
# 117
# Fooled s:
# 5
# images processed: 533
# Fooled z:
# 117
# Fooled s:
# 5
# images processed: 534
# Fooled z:
# 118
# Fooled s:
# 5
# images processed: 535
# Fooled z:
# 119
# Fooled s:
# 5
# images processed: 536
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 537
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 538
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 539
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 540
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 541
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 542
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 543
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 544
# Fooled z:
# 120
# Fooled s:
# 5
# images processed: 545
# Fooled z:
# 121
# Fooled s:
# 5
# images processed: 546
# Fooled z:
# 121
# Fooled s:
# 5
# images processed: 547
# Fooled z:
# 121
# Fooled s:
# 5
# images processed: 548
# Fooled z:
# 121
# Fooled s:
# 5
# images processed: 549
# Fooled z:
# 122
# Fooled s:
# 5
# images processed: 550
# Fooled z:
# 122
# Fooled s:
# 5
# images processed: 551
# Fooled z:
# 122
# Fooled s:
# 5
# images processed: 552
# Fooled z:
# 123
# Fooled s:
# 5
# images processed: 553
# Fooled z:
# 123
# Fooled s:
# 5
# images processed: 554
# Fooled z:
# 124
# Fooled s:
# 5
# images processed: 555
# Fooled z:
# 124
# Fooled s:
# 5
# images processed: 556
# Fooled z:
# 124
# Fooled s:
# 5
# images processed: 557
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 558
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 559
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 560
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 561
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 562
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 563
# Fooled z:
# 125
# Fooled s:
# 5
# images processed: 564
# Fooled z:
# 126
# Fooled s:
# 5
# images processed: 565
# Fooled z:
# 126
# Fooled s:
# 5
# images processed: 566
# Fooled z:
# 127
# Fooled s:
# 5
# images processed: 567
# Fooled z:
# 127
# Fooled s:
# 5
# images processed: 568
# Fooled z:
# 127
# Fooled s:
# 5
# images processed: 569
# Fooled z:
# 127
# Fooled s:
# 5
# images processed: 570
# Fooled z:
# 128
# Fooled s:
# 5
# images processed: 571
# Fooled z:
# 128
# Fooled s:
# 5
# images processed: 572
# Fooled z:
# 128
# Fooled s:
# 5
# images processed: 573
# Fooled z:
# 129
# Fooled s:
# 5
# images processed: 574
# Fooled z:
# 129
# Fooled s:
# 5
# images processed: 575
# Fooled z:
# 130
# Fooled s:
# 5
# images processed: 576
# Fooled z:
# 131
# Fooled s:
# 5
# images processed: 577
# Fooled z:
# 131
# Fooled s:
# 5
# images processed: 578
# Fooled z:
# 132
# Fooled s:
# 5
# images processed: 579
# Fooled z:
# 132
# Fooled s:
# 5
# images processed: 580
# Fooled z:
# 133
# Fooled s:
# 5
# images processed: 581
# Fooled z:
# 133
# Fooled s:
# 5
# images processed: 582
# Fooled z:
# 134
# Fooled s:
# 5
# images processed: 583
# Fooled z:
# 134
# Fooled s:
# 5
# images processed: 584
# Fooled z:
# 135
# Fooled s:
# 5
# images processed: 585
# Fooled z:
# 136
# Fooled s:
# 5
# images processed: 586
# Fooled z:
# 136
# Fooled s:
# 5
# images processed: 587
# Fooled z:
# 136
# Fooled s:
# 5
# images processed: 588
# Fooled z:
# 136
# Fooled s:
# 5
# images processed: 589
# Fooled z:
# 137
# Fooled s:
# 5
# images processed: 590
# Fooled z:
# 137
# Fooled s:
# 5
# images processed: 591
# Fooled z:
# 138
# Fooled s:
# 5
# images processed: 592
# Fooled z:
# 139
# Fooled s:
# 5
# images processed: 593
# Fooled z:
# 140
# Fooled s:
# 5
# images processed: 594
# Fooled z:
# 141
# Fooled s:
# 5
# images processed: 595
# Fooled z:
# 142
# Fooled s:
# 5
# images processed: 596
# Fooled z:
# 143
# Fooled s:
# 5
# images processed: 597
# Fooled z:
# 143
# Fooled s:
# 5
# images processed: 598
# Fooled z:
# 143
# Fooled s:
# 5
# images processed: 599
# Fooled z:
# 144
# Fooled s:
# 6
# images processed: 600
# Fooled z:
# 145
# Fooled s:
# 6
# images processed: 601
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 602
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 603
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 604
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 605
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 606
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 607
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 608
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 609
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 610
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 611
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 612
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 613
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 614
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 615
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 616
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 617
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 618
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 619
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 620
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 621
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 622
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 623
# Fooled z:
# 146
# Fooled s:
# 6
# images processed: 624
# Fooled z:
# 147
# Fooled s:
# 6
# images processed: 625
# Fooled z:
# 147
# Fooled s:
# 6
# images processed: 626
# Fooled z:
# 147
# Fooled s:
# 6
# images processed: 627
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 628
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 629
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 630
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 631
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 632
# Fooled z:
# 148
# Fooled s:
# 6
# images processed: 633
# Fooled z:
# 149
# Fooled s:
# 6
# images processed: 634
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 635
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 636
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 637
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 638
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 639
# Fooled z:
# 150
# Fooled s:
# 6
# images processed: 640
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 641
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 642
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 643
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 644
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 645
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 646
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 647
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 648
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 649
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 650
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 651
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 652
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 653
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 654
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 655
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 656
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 657
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 658
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 659
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 660
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 661
# Fooled z:
# 151
# Fooled s:
# 6
# images processed: 662
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 663
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 664
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 665
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 666
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 667
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 668
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 669
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 670
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 671
# Fooled z:
# 152
# Fooled s:
# 6
# images processed: 672
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 673
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 674
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 675
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 676
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 677
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 678
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 679
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 680
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 681
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 682
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 683
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 684
# Fooled z:
# 153
# Fooled s:
# 6
# images processed: 685
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 686
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 687
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 688
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 689
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 690
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 691
# Fooled z:
# 154
# Fooled s:
# 6
# images processed: 692
# Fooled z:
# 155
# Fooled s:
# 6
# images processed: 693
# Fooled z:
# 155
# Fooled s:
# 6
# images processed: 694
# Fooled z:
# 155
# Fooled s:
# 6
# images processed: 695
# Fooled z:
# 156
# Fooled s:
# 6
# images processed: 696
# Fooled z:
# 156
# Fooled s:
# 6
# images processed: 697
# Fooled z:
# 157
# Fooled s:
# 6
# images processed: 698
# Fooled z:
# 158
# Fooled s:
# 6
# images processed: 699
# Fooled z:
# 158
# Fooled s:
# 6
# images processed: 700
# Fooled z:
# 159
# Fooled s:
# 6
# images processed: 701
# Fooled z:
# 159
# Fooled s:
# 6
# images processed: 702
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 703
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 704
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 705
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 706
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 707
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 708
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 709
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 710
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 711
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 712
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 713
# Fooled z:
# 160
# Fooled s:
# 6
# images processed: 714
# Fooled z:
# 161
# Fooled s:
# 6
# images processed: 715
# Fooled z:
# 161
# Fooled s:
# 6
# images processed: 716
# Fooled z:
# 161
# Fooled s:
# 6
# images processed: 717
# Fooled z:
# 161
# Fooled s:
# 6
# images processed: 718
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 719
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 720
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 721
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 722
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 723
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 724
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 725
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 726
# Fooled z:
# 162
# Fooled s:
# 6
# images processed: 727
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 728
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 729
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 730
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 731
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 732
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 733
# Fooled z:
# 163
# Fooled s:
# 6
# images processed: 734
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 735
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 736
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 737
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 738
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 739
# Fooled z:
# 164
# Fooled s:
# 6
# images processed: 740
# Fooled z:
# 165
# Fooled s:
# 6
# images processed: 741
# Fooled z:
# 166
# Fooled s:
# 6
# images processed: 742
# Fooled z:
# 166
# Fooled s:
# 6
# images processed: 743
# Fooled z:
# 166
# Fooled s:
# 6
# images processed: 744
# Fooled z:
# 167
# Fooled s:
# 6
# images processed: 745
# Fooled z:
# 167
# Fooled s:
# 6
# images processed: 746
# Fooled z:
# 168
# Fooled s:
# 6
# images processed: 747
# Fooled z:
# 168
# Fooled s:
# 6
# images processed: 748
# Fooled z:
# 168
# Fooled s:
# 6
# images processed: 749
# Fooled z:
# 168
# Fooled s:
# 6
# images processed: 750
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 751
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 752
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 753
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 754
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 755
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 756
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 757
# Fooled z:
# 169
# Fooled s:
# 6
# images processed: 758
# Fooled z:
# 170
# Fooled s:
# 6
# images processed: 759
# Fooled z:
# 170
# Fooled s:
# 6
# images processed: 760
# Fooled z:
# 170
# Fooled s:
# 6
# images processed: 761
# Fooled z:
# 170
# Fooled s:
# 6
# images processed: 762
# Fooled z:
# 171
# Fooled s:
# 6
# images processed: 763
# Fooled z:
# 171
# Fooled s:
# 6
# images processed: 764
# Fooled z:
# 172
# Fooled s:
# 6
# images processed: 765
# Fooled z:
# 173
# Fooled s:
# 6
# images processed: 766
# Fooled z:
# 173
# Fooled s:
# 6
# images processed: 767
# Fooled z:
# 173
# Fooled s:
# 6
# images processed: 768
# Fooled z:
# 173
# Fooled s:
# 6
# images processed: 769
# Fooled z:
# 173
# Fooled s:
# 6
# images processed: 770
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 771
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 772
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 773
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 774
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 775
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 776
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 777
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 778
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 779
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 780
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 781
# Fooled z:
# 174
# Fooled s:
# 6
# images processed: 782
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 783
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 784
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 785
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 786
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 787
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 788
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 789
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 790
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 791
# Fooled z:
# 175
# Fooled s:
# 6
# images processed: 792
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 793
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 794
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 795
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 796
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 797
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 798
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 799
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 800
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 801
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 802
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 803
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 804
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 805
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 806
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 807
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 808
# Fooled z:
# 176
# Fooled s:
# 6
# images processed: 809
# Fooled z:
# 177
# Fooled s:
# 6
# images processed: 810
# Fooled z:
# 177
# Fooled s:
# 6
# images processed: 811
# Fooled z:
# 177
# Fooled s:
# 6
# images processed: 812
# Fooled z:
# 177
# Fooled s:
# 6
# images processed: 813
# Fooled z:
# 177
# Fooled s:
# 6
# images processed: 814
# Fooled z:
# 178
# Fooled s:
# 6
# images processed: 815
# Fooled z:
# 178
# Fooled s:
# 6
# images processed: 816
# Fooled z:
# 179
# Fooled s:
# 7
# images processed: 817
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 818
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 819
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 820
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 821
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 822
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 823
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 824
# Fooled z:
# 180
# Fooled s:
# 7
# images processed: 825
# Fooled z:
# 181
# Fooled s:
# 7
# images processed: 826
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 827
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 828
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 829
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 830
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 831
# Fooled z:
# 182
# Fooled s:
# 7
# images processed: 832
# Fooled z:
# 183
# Fooled s:
# 7
# images processed: 833
# Fooled z:
# 183
# Fooled s:
# 7
# images processed: 834
# Fooled z:
# 183
# Fooled s:
# 7
# images processed: 835
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 836
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 837
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 838
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 839
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 840
# Fooled z:
# 184
# Fooled s:
# 8
# images processed: 841
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 842
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 843
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 844
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 845
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 846
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 847
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 848
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 849
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 850
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 851
# Fooled z:
# 185
# Fooled s:
# 8
# images processed: 852
# Fooled z:
# 186
# Fooled s:
# 9
# images processed: 853
# Fooled z:
# 186
# Fooled s:
# 9
# images processed: 854
# Fooled z:
# 186
# Fooled s:
# 9
# images processed: 855
# Fooled z:
# 186
# Fooled s:
# 9
# images processed: 856
# Fooled z:
# 186
# Fooled s:
# 9
# images processed: 857
# Fooled z:
# 187
# Fooled s:
# 9
# images processed: 858
# Fooled z:
# 187
# Fooled s:
# 9
# images processed: 859
# Fooled z:
# 188
# Fooled s:
# 9
# images processed: 860
# Fooled z:
# 188
# Fooled s:
# 9
# images processed: 861
# Fooled z:
# 188
# Fooled s:
# 9
# images processed: 862
# Fooled z:
# 189
# Fooled s:
# 9
# images processed: 863
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 864
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 865
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 866
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 867
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 868
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 869
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 870
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 871
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 872
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 873
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 874
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 875
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 876
# Fooled z:
# 190
# Fooled s:
# 9
# images processed: 877
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 878
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 879
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 880
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 881
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 882
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 883
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 884
# Fooled z:
# 191
# Fooled s:
# 9
# images processed: 885
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 886
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 887
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 888
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 889
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 890
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 891
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 892
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 893
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 894
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 895
# Fooled z:
# 192
# Fooled s:
# 9
# images processed: 896
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 897
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 898
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 899
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 900
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 901
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 902
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 903
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 904
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 905
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 906
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 907
# Fooled z:
# 193
# Fooled s:
# 9
# images processed: 908
# Fooled z:
# 194
# Fooled s:
# 9
# images processed: 909
# Fooled z:
# 194
# Fooled s:
# 9
# images processed: 910
# Fooled z:
# 194
# Fooled s:
# 9
# images processed: 911
# Fooled z:
# 195
# Fooled s:
# 9
# images processed: 912
# Fooled z:
# 196
# Fooled s:
# 9
# images processed: 913
# Fooled z:
# 196
# Fooled s:
# 9
# images processed: 914
# Fooled z:
# 196
# Fooled s:
# 9
# images processed: 915
# Fooled z:
# 196
# Fooled s:
# 9
# images processed: 916
# Fooled z:
# 196
# Fooled s:
# 9
# images processed: 917
# Fooled z:
# 197
# Fooled s:
# 9
# images processed: 918
# Fooled z:
# 197
# Fooled s:
# 9
# images processed: 919
# Fooled z:
# 198
# Fooled s:
# 9
# images processed: 920
# Fooled z:
# 199
# Fooled s:
# 9
# images processed: 921
# Fooled z:
# 200
# Fooled s:
# 9
# images processed: 922
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 923
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 924
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 925
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 926
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 927
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 928
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 929
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 930
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 931
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 932
# Fooled z:
# 201
# Fooled s:
# 9
# images processed: 933
# Fooled z:
# 202
# Fooled s:
# 9
# images processed: 934
# Fooled z:
# 202
# Fooled s:
# 9
# images processed: 935
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 936
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 937
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 938
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 939
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 940
# Fooled z:
# 203
# Fooled s:
# 9
# images processed: 941
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 942
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 943
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 944
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 945
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 946
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 947
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 948
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 949
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 950
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 951
# Fooled z:
# 204
# Fooled s:
# 9
# images processed: 952
# Fooled z:
# 205
# Fooled s:
# 9
# images processed: 953
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 954
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 955
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 956
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 957
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 958
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 959
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 960
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 961
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 962
# Fooled z:
# 206
# Fooled s:
# 9
# images processed: 963
# Fooled z:
# 207
# Fooled s:
# 9
# images processed: 964
# Fooled z:
# 207
# Fooled s:
# 9
# images processed: 965
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 966
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 967
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 968
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 969
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 970
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 971
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 972
# Fooled z:
# 208
# Fooled s:
# 9
# images processed: 973
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 974
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 975
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 976
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 977
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 978
# Fooled z:
# 208
# Fooled s:
# 10
# images processed: 979
# Fooled z:
# 209
# Fooled s:
# 10
# images processed: 980
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 981
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 982
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 983
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 984
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 985
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 986
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 987
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 988
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 989
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 990
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 991
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 992
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 993
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 994
# Fooled z:
# 210
# Fooled s:
# 10
# images processed: 995
# Fooled z:
# 211
# Fooled s:
# 10
# images processed: 996
# Fooled z:
# 211
# Fooled s:
# 10
# images processed: 997
# Fooled z:
# 211
# Fooled s:
# 10
# images processed: 998
# Fooled z:
# 211
# Fooled s:
# 10
# images processed: 999
# Fooled z:
# 211
# Fooled s:
# 10
# images processed: 1000
# Fooled z %:
# 21.099999999999998
# Fooled s %:
# 1.0
